# %%
# !pip install matplotlib
# !pip install pandas
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp311-cp311-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (11.0.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\happp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 5.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 5.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pyparsing-3.2.3
# Requirement already satisfied: pandas in c:\users\happp\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\happp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 設定顏色變數
line_color = '#019a7b'  # 預設顏色是藍色，你可以修改這裡

# 讀取 CSV 文件
data = pd.read_csv(r'C:\Users\happp\OneDrive\文件\2025_Rocket\Arduino\Launch_Test\Sim_Data.csv')  # 替換為你的文件名稱

# %%
# 函數：讀取指定的數據列並繪製圖表
def plot_data(time_col, data_col, unit_1, unit_2):
    plt.figure(dpi=300)  # 提高畫質
    plt.plot(data[time_col], data[data_col], color=line_color)
    plt.xlabel(f"{time_col} ({unit_1})")
    plt.ylabel(f"{data_col} ({unit_2})")
    plt.title(f'{time_col} vs {data_col}')
    plt.grid(True)
    plt.show()

# %%
# 用法範例：你可以指定要繪製的數據列
# Altitude,Vertical_Velocity,Acceleration,Pressure
plot_data('Time', 'Vertical_Velocity', "s", "m/s")  # 將 'Altitude' 換成其他列名

# %%
# 提取特定列並保存為垂直格式的 CSV 文件
def extract_column_and_save_as_vertical_csv(column_name, output_csv_filename):
    # 提取特定列
    column_data = data[[column_name]]
    
    # 保存為新的 CSV 文件，垂直格式
    column_data.to_csv(output_csv_filename, header=True, index=False)  # 保留列名，且不輸出索引

# %%
# 使用範例：提取 'Press'（氣壓）列並保存為垂直格式的 CSV 文件
extract_column_and_save_as_vertical_csv('Pressure', 'output_pressure.csv')
