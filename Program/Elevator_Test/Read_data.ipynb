# %%
# !pip install matplotlib pandas
# Out:
# Requirement already satisfied: matplotlib in c:\users\happp\anaconda3\lib\site-packages (3.10.1)
# Requirement already satisfied: pandas in c:\users\happp\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\happp\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\happp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\happp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 顏色變數
color_alt = '#019a7b'
color_slope = '#1f318f'

# 讀取 CSV
df = pd.read_csv(r'C:\Users\happp\OneDrive\文件\2025_Rocket\0412T2.csv')

# %%
# 畫圖
fig, ax1 = plt.subplots(dpi=300)

# 左邊 y 軸：average_alt
ax1.set_xlabel('Time(ms)')
ax1.set_ylabel('Average Altitude(m)', color=color_alt)
ax1.plot(df["Time"], df["Ave_Alt"], color=color_alt, label='Average Altitude')
ax1.tick_params(axis='y', labelcolor=color_alt)
ax1.set_ylim(-20, 60)

# 加入左邊 0 線
ax1.axhline(0, color='gray', linestyle='--', linewidth=1, alpha=0.6)

# 右邊 y 軸：slope
ax2 = ax1.twinx()
ax2.set_ylabel('Slope(m/s)', color=color_slope)
ax2.plot(df["Time"], df["Slope"], color=color_slope, label='Slope')
ax2.tick_params(axis='y', labelcolor=color_slope)
ax2.set_ylim(-3, 9)

# 加入右邊 0 線
ax2.axhline(0, color='gray', linestyle='--', linewidth=1, alpha=0.6)

# 加入垂直線（假設在 Time = 5000 毫秒）
vertical_time = 347658
ax1.axvline(x=vertical_time, color='red', linestyle='--', linewidth=1, alpha=0.8)

# 顯示圖
plt.title("Average Altitude and Slope Over Time")
fig.tight_layout()  
plt.show()

# %%
# 顏色設定
color_alt1 = '#019a7b'
color_alt2 = '#1f318f'
color_avg = 'black'

# %%
# 畫圖
fig, ax = plt.subplots(dpi=300)

# 繪製 alt_1、alt_2、average_alt
ax.plot(df["Time"], df["average_alt"], label="Average Alt", linestyle='-', color=color_avg)
ax.plot(df["Time"], df["alt_1"], label="Alt 1", linestyle='--', color=color_alt1)
ax.plot(df["Time"], df["alt_2"], label="Alt 2", linestyle='--', color=color_alt2)

# 標題與標籤
ax.set_xlabel("Time(ms)")
ax.set_ylabel("Altitude(m)")
ax.set_title("Alt 1, Alt 2, and Average Altitude Over Time")

# 顯示圖例
ax.legend()

# 加上下邊界 padding
alt_min = min(df["alt_1"].min(), df["alt_2"].min(), df["average_alt"].min())
alt_max = max(df["alt_1"].max(), df["alt_2"].max(), df["average_alt"].max())
padding = (alt_max - alt_min) * 0.1
ax.set_ylim(alt_min - padding, alt_max + padding)

# 顯示圖
plt.tight_layout()
plt.show()
